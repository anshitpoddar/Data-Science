# %%
import random

Age = []
for i in range(1000):
    age = random.randint(60,70)
    Age.append(age);
Age
# Out:
# [69,
#  61,
#  70,
#  61,
#  63,
#  62,
#  67,
#  65,
#  65,
#  61,
#  61,
#  62,
#  60,
#  66,
#  60,
#  61,
#  69,
#  68,
#  63,
#  68,
#  65,
#  65,
#  65,
#  60,
#  63,
#  70,
#  70,
#  68,
#  66,
#  67,
#  64,
#  61,
#  65,
#  60,
#  65,
#  67,
#  63,
#  61,
#  61,
#  69,
#  60,
#  60,
#  67,
#  61,
#  63,
#  64,
#  68,
#  70,
#  69,
#  61,
#  60,
#  69,
#  69,
#  60,
#  67,
#  67,
#  65,
#  62,
#  63,
#  65,
#  60,
#  62,
#  70,
#  69,
#  68,
#  67,
#  60,
#  70,
#  63,
#  62,
#  62,
#  68,
#  67,
#  61,
#  67,
#  65,
#  67,
#  63,
#  62,
#  63,
#  68,
#  67,
#  68,
#  64,
#  61,
#  69,
#  69,
#  69,
#  69,
#  65,
#  63,
#  64,
#  63,
#  62,
#  66,
#  69,
#  63,
#  61,
#  70,
#  60,
#  70,
#  67,
#  63,
#  67,
#  64,
#  61,
#  68,
#  64,
#  67,
#  64,
#  63,
#  69,
#  67,
#  63,
#  61,
#  67,
#  67,
#  64,
#  61,
#  61,
#  66,
#  67,
#  62,
#  69,
#  64,
#  64,
#  60,
#  62,
#  70,
#  63,
#  63,
#  63,
#  69,
#  63,
#  67,
#  63,
#  62,
#  68,
#  65,
#  68,
#  62,
#  67,
#  66,
#  63,
#  70,
#  64,
#  60,
#  61,
#  64,
#  70,
#  60,
#  67,
#  60,
#  61,
#  65,
#  64,
#  63,
#  68,
#  70,
#  61,
#  63,
#  68,
#  62,
#  65,
#  65,
#  68,
#  68,
#  65,
#  61,
#  63,
#  68,
#  70,
#  63,
#  61,
#  65,
#  60,
#  66,
#  70,
#  64,
#  68,
#  63,
#  62,
#  69,
#  64,
#  68,
#  68,
#  60,
#  60,
#  60,
#  70,
#  67,
#  62,
#  67,
#  63,
#  69,
#  60,
#  68,
#  69,
#  64,
#  60,
#  70,
#  65,
#  61,
#  66,
#  70,
#  69,
#  62,
#  61,
#  69,
#  65,
#  61,
#  70,
#  67,
#  62,
#  61,
#  62,
#  64,
#  65,
#  60,
#  61,
#  63,
#  64,
#  62,
#  67,
#  62,
#  62,
#  61,
#  64,
#  64,
#  60,
#  66,
#  61,
#  68,
#  61,
#  61,
#  69,
#  67,
#  70,
#  60,
#  70,
#  68,
#  67,
#  61,
#  66,
#  66,
#  60,
#  63,
#  61,
#  63,
#  62,
#  67,
#  68,
#  63,
#  68,
#  60,
#  70,
#  65,
#  67,
#  65,
#  65,
#  69,
#  67,
#  64,
#  68,
#  68,
#  64,
#  62,
#  66,
#  64,
#  65,
#  64,
#  70,
#  69,
#  68,
#  65,
#  66,
#  69,
#  65,
#  70,
#  62,
#  67,
#  69,
#  63,
#  60,
#  60,
#  63,
#  63,
#  64,
#  70,
#  69,
#  61,
#  60,
#  61,
#  60,
#  68,
#  68,
#  70,
#  64,
#  70,
#  68,
#  60,
#  64,
#  70,
#  69,
#  61,
#  69,
#  66,
#  65,
#  65,
#  70,
#  61,
#  68,
#  63,
#  68,
#  68,
#  67,
#  63,
#  64,
#  70,
#  66,
#  69,
#  68,
#  63,
#  67,
#  70,
#  64,
#  63,
#  65,
#  65,
#  61,
#  64,
#  68,
#  63,
#  62,
#  70,
#  69,
#  60,
#  66,
#  66,
#  70,
#  65,
#  65,
#  63,
#  61,
#  65,
#  63,
#  61,
#  69,
#  62,
#  68,
#  68,
#  63,
#  65,
#  63,
#  61,
#  62,
#  60,
#  62,
#  64,
#  64,
#  70,
#  61,
#  67,
#  63,
#  61,
#  63,
#  68,
#  67,
#  61,
#  65,
#  61,
#  65,
#  68,
#  63,
#  62,
#  62,
#  60,
#  68,
#  70,
#  63,
#  67,
#  69,
#  66,
#  61,
#  60,
#  60,
#  61,
#  65,
#  64,
#  62,
#  67,
#  62,
#  64,
#  69,
#  62,
#  65,
#  63,
#  62,
#  67,
#  61,
#  65,
#  69,
#  62,
#  61,
#  69,
#  62,
#  70,
#  65,
#  62,
#  63,
#  68,
#  62,
#  69,
#  61,
#  61,
#  66,
#  62,
#  61,
#  69,
#  70,
#  61,
#  61,
#  70,
#  67,
#  66,
#  66,
#  68,
#  68,
#  69,
#  64,
#  63,
#  66,
#  69,
#  67,
#  67,
#  61,
#  70,
#  70,
#  66,
#  60,
#  61,
#  61,
#  69,
#  68,
#  64,
#  70,
#  63,
#  66,
#  62,
#  64,
#  63,
#  62,
#  70,
#  66,
#  60,
#  69,
#  67,
#  66,
#  64,
#  65,
#  60,
#  68,
#  62,
#  65,
#  60,
#  60,
#  69,
#  62,
#  60,
#  60,
#  68,
#  62,
#  62,
#  67,
#  68,
#  65,
#  60,
#  61,
#  62,
#  70,
#  69,
#  68,
#  65,
#  63,
#  64,
#  70,
#  62,
#  65,
#  65,
#  63,
#  70,
#  61,
#  62,
#  65,
#  66,
#  64,
#  67,
#  61,
#  64,
#  65,
#  69,
#  64,
#  63,
#  62,
#  69,
#  68,
#  69,
#  62,
#  66,
#  62,
#  62,
#  67,
#  68,
#  70,
#  69,
#  69,
#  60,
#  61,
#  65,
#  66,
#  62,
#  68,
#  64,
#  61,
#  69,
#  66,
#  65,
#  67,
#  62,
#  66,
#  69,
#  68,
#  65,
#  64,
#  61,
#  60,
#  61,
#  65,
#  69,
#  60,
#  70,
#  67,
#  70,
#  68,
#  65,
#  62,
#  65,
#  66,
#  66,
#  66,
#  70,
#  69,
#  62,
#  69,
#  69,
#  70,
#  68,
#  67,
#  67,
#  69,
#  67,
#  60,
#  66,
#  68,
#  66,
#  66,
#  60,
#  63,
#  61,
#  62,
#  65,
#  62,
#  63,
#  63,
#  68,
#  62,
#  69,
#  60,
#  63,
#  69,
#  60,
#  62,
#  68,
#  66,
#  63,
#  66,
#  61,
#  64,
#  66,
#  60,
#  67,
#  64,
#  65,
#  67,
#  62,
#  70,
#  68,
#  61,
#  66,
#  64,
#  64,
#  61,
#  69,
#  64,
#  65,
#  60,
#  69,
#  60,
#  63,
#  65,
#  60,
#  66,
#  70,
#  67,
#  68,
#  64,
#  68,
#  63,
#  66,
#  67,
#  60,
#  62,
#  60,
#  69,
#  65,
#  64,
#  62,
#  66,
#  68,
#  65,
#  65,
#  66,
#  62,
#  62,
#  68,
#  68,
#  67,
#  66,
#  62,
#  70,
#  68,
#  69,
#  62,
#  66,
#  67,
#  68,
#  61,
#  60,
#  62,
#  68,
#  70,
#  60,
#  66,
#  70,
#  70,
#  70,
#  63,
#  69,
#  68,
#  68,
#  70,
#  65,
#  60,
#  60,
#  68,
#  70,
#  67,
#  65,
#  61,
#  63,
#  64,
#  64,
#  66,
#  62,
#  61,
#  67,
#  67,
#  64,
#  63,
#  62,
#  63,
#  60,
#  65,
#  64,
#  66,
#  70,
#  61,
#  69,
#  68,
#  66,
#  67,
#  65,
#  67,
#  64,
#  66,
#  64,
#  60,
#  64,
#  65,
#  69,
#  67,
#  62,
#  70,
#  61,
#  64,
#  69,
#  68,
#  67,
#  63,
#  70,
#  70,
#  70,
#  64,
#  66,
#  60,
#  67,
#  63,
#  64,
#  66,
#  60,
#  65,
#  63,
#  64,
#  60,
#  68,
#  69,
#  66,
#  64,
#  67,
#  61,
#  65,
#  66,
#  70,
#  65,
#  70,
#  66,
#  65,
#  67,
#  66,
#  64,
#  66,
#  65,
#  65,
#  63,
#  63,
#  69,
#  69,
#  69,
#  61,
#  66,
#  65,
#  62,
#  60,
#  70,
#  68,
#  62,
#  64,
#  62,
#  70,
#  60,
#  67,
#  68,
#  62,
#  66,
#  65,
#  67,
#  65,
#  62,
#  62,
#  66,
#  64,
#  69,
#  65,
#  65,
#  61,
#  62,
#  64,
#  67,
#  67,
#  61,
#  63,
#  63,
#  64,
#  67,
#  64,
#  67,
#  69,
#  69,
#  64,
#  67,
#  60,
#  69,
#  66,
#  70,
#  60,
#  62,
#  67,
#  62,
#  66,
#  65,
#  68,
#  60,
#  63,
#  67,
#  60,
#  62,
#  65,
#  65,
#  60,
#  65,
#  70,
#  62,
#  68,
#  63,
#  62,
#  62,
#  68,
#  66,
#  65,
#  60,
#  66,
#  63,
#  65,
#  62,
#  61,
#  60,
#  64,
#  62,
#  62,
#  65,
#  61,
#  62,
#  64,
#  68,
#  65,
#  64,
#  65,
#  69,
#  69,
#  62,
#  67,
#  61,
#  65,
#  64,
#  61,
#  67,
#  60,
#  67,
#  63,
#  63,
#  62,
#  67,
#  69,
#  65,
#  69,
#  61,
#  62,
#  61,
#  63,
#  62,
#  69,
#  70,
#  68,
#  65,
#  70,
#  64,
#  68,
#  62,
#  68,
#  66,
#  64,
#  70,
#  66,
#  63,
#  64,
#  60,
#  62,
#  65,
#  66,
#  62,
#  68,
#  60,
#  62,
#  62,
#  60,
#  70,
#  63,
#  66,
#  62,
#  64,
#  63,
#  64,
#  65,
#  69,
#  60,
#  63,
#  64,
#  67,
#  70,
#  65,
#  70,
#  70,
#  68,
#  63,
#  64,
#  64,
#  60,
#  62,
#  61,
#  64,
#  66,
#  68,
#  62,
#  67,
#  68,
#  66,
#  65,
#  67,
#  68,
#  64,
#  69,
#  62,
#  70,
#  63,
#  70,
#  69,
#  69,
#  68,
#  69,
#  67,
#  68,
#  63,
#  70,
#  65,
#  60,
#  60,
#  64,
#  70,
#  63,
#  66,
#  64,
#  60,
#  70,
#  68,
#  62,
#  68,
#  68,
#  61,
#  66,
#  60,
#  60,
#  60,
#  61,
#  64,
#  66,
#  65,
#  64,
#  67,
#  61,
#  63,
#  66,
#  60,
#  66,
#  67,
#  68,
#  65,
#  61,
#  68,
#  67,
#  67,
#  65,
#  68,
#  70,
#  66,
#  66,
#  60,
#  69,
#  66,
#  60,
#  65,
#  61,
#  65,
#  70,
#  68,
#  61,
#  65,
#  62,
#  66,
#  63,
#  65,
#  64,
#  68,
#  68,
#  64,
#  70,
#  69,
#  67,
#  64,
#  65,
#  68]

# %%
import numpy as np

Age = np.array(Age)


mean = np.mean(age)
std= np.std(Age)
mean,std
# Out:
# (68.0, 3.1355886209769293)

# %%
import matplotlib.pyplot as plt

plt.hist(Age,bins= 22)
plt.xlabel("Age")
plt.ylabel("Frequency")
plt.title("Frequency chart of ages")
plt.show()

# %%
'''generated the ages randomly from a uniform
distribution between 60 and 70'''
# Out:
# 'generated the ages randomly from a uniform\ndistribution between 60 and 70'

# %%
sample= np.random.choice(Age,size = 30)

# %%
s_mean = []
s_mean.append(np.mean(sample))
s_mean
# Out:
# [65.23333333333333]

# %%
for i in range(0,499):
    sample= np.random.choice(Age,size = 30)
    s_mean.append(np.mean(sample))

# %%
np.size(s_mean)
# Out:
# 500

# %%
plt.hist(s_mean,bins=20)
plt.xlabel("sample mean")
plt.ylabel("frequency")
plt.title("Frequecy vs sample_mean")
# Out:
# Text(0.5, 1.0, 'Frequecy vs sample_mean')

# %%
s_mean = np.array(s_mean)
np.mean(s_mean),np.std(s_mean)
# Out:
# (64.9242, 0.5961272459243356)

# %%
np.mean(s_mean),mean
# Out:
# (64.9242, 68.0)

# %%
np.std(s_mean),std/(30**0.5)
# Out:
# (0.5961272459243356, 0.5724775395885269)

# %%
sample= np.random.choice(Age,size = 50)
s_mean = []
s_mean.append(np.mean(sample))
s_mean
# Out:
# [65.36]

# %%
for i in range(0,499):
    sample= np.random.choice(Age,size = 50)
    s_mean.append(np.mean(sample))

# %%
plt.hist(s_mean,bins=15)
plt.xlabel("sample mean")
plt.ylabel("frequency")
plt.title("Frequecy vs sample_mean")
# Out:
# Text(0.5, 1.0, 'Frequecy vs sample_mean')

# %%
s_mean = np.array(s_mean)
np.mean(s_mean),np.std(s_mean)
# Out:
# (64.89784, 0.44598669755946774)

# %%
np.mean(s_mean),mean
# Out:
# (64.89784, 68.0)

# %%
np.std(s_mean),std/(50**0.5)
# Out:
# (0.44598669755946774, 0.4434391953808324)

# %%
'''here are the results'''
# Out:
# 'here are the results'
